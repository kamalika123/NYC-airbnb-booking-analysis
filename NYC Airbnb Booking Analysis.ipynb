# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
airbnb = pd.read_csv(r"AB_NYC_2019.csv")
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
airbnb.drop(['latitude','longitude','last_review','reviews_per_month'],axis=1,inplace=True)

# %%
airbnb.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood        room_type  \
# 0         John            Brooklyn          Kensington     Private room
# 1     Jennifer           Manhattan             Midtown  Entire home/apt
# ...

# %%
#count of duplicate values
airbnb.duplicated(keep = False).sum()
# Out:
# 0

# %%
#filling the null values in name and host_name column with 'Unknown'
airbnb['name'].fillna('Unknown', inplace=True)
airbnb['host_name'].fillna('Unknown', inplace=True)

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  calculated_host_listings_count  48895 non-null  int64
#  11  availability_365                48895 non-null  int64
# ...

# %%
# Calculate the IQR (Interquartile Range)
Q1 = airbnb['price'].quantile(0.25)
Q3 = airbnb['price'].quantile(0.75)
IQR = Q3 - Q1

# Define the boundaries for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = airbnb[(airbnb['price'] < lower_bound) | (airbnb['price'] > upper_bound)]

# %%
print(outliers)
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 114       26933  2 BR / 2 Bath Duplex Apt with patio! East Village      72062
# 121       27659                   3 Story Town House in Park Slope     119588
# ...         ...                                                ...        ...
# 48758  36420289    Rustic Garden House Apt, 2 stops from Manhattan   73211393
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
# 48842  36453160  LUXURY MANHATTAN PENTHOUSE+HUDSON RIVER+EMPIRE...  224171371
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
#
# ...

# %%
# Assuming 'outliers' contains the DataFrame rows identified as outliers
airbnb_cleaned = airbnb.drop(outliers.index)

# %%
# Grouping by 'host_id' and 'host_name' to check consistency
host_id_name_consistency = airbnb.groupby(['host_id', 'host_name']).size().reset_index(name='count')

# Checking for inconsistencies where a host_id has multiple different host_names
inconsistent_hosts = host_id_name_consistency[host_id_name_consistency.duplicated(subset='host_id', keep=False)]

if inconsistent_hosts.empty:
    print("No inconsistencies found between 'host_id' and 'host_name'.")
else:
    print("Inconsistencies found between 'host_id' and 'host_name':")
    print(inconsistent_hosts)
# Out:
# No inconsistencies found between 'host_id' and 'host_name'.

# %%
# Check if the 'minimum_nights' column contains only positive integers
is_positive_int = all(airbnb['minimum_nights'] > 0) and all(airbnb['minimum_nights'] == airbnb['minimum_nights'].astype(int))

if is_positive_int:
    print("The 'minimum_nights' column contains only positive integers.")
else:
    print("The 'minimum_nights' column does not contain only positive integers.")
# Out:
# The 'minimum_nights' column contains only positive integers.

# %% [markdown]
# # Information about different host and areas

# %%
host_areas = airbnb.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
host_areas.sort_values(by='calculated_host_listings_count',ascending=False).head(10)
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                             327
# 1833          Blueground            Brooklyn                             232
# 1834          Blueground           Manhattan                             232
# 7275                Kara           Manhattan                             121
# 7480              Kazuya              Queens                             103
# 7479              Kazuya           Manhattan                             103
# 7478              Kazuya            Brooklyn                             103
# 6540      Jeremy & Laura           Manhattan                              96
# 13216             Sonder           Manhattan                              96
# 2901   Corporate Housing           Manhattan                              91

# %% [markdown]
# # Room Prices according to the area

# %%
room_price_area_wise = airbnb.groupby(['room_type','neighbourhood_group'])['price'].max().reset_index()
room_price_area_wise.sort_values(by='price',ascending=False).head(10)
# Out:
#           room_type neighbourhood_group  price
# 1   Entire home/apt            Brooklyn  10000
# 2   Entire home/apt           Manhattan  10000
# 8      Private room              Queens  10000
# 7      Private room           Manhattan   9999
# 6      Private room            Brooklyn   7500
# 4   Entire home/apt       Staten Island   5000
# 3   Entire home/apt              Queens   2600
# 5      Private room               Bronx   2500
# 13      Shared room              Queens   1800
# 0   Entire home/apt               Bronx   1000

# %% [markdown]
# # Room Types and Neighbourhoods

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='room_type', data=airbnb, hue='neighbourhood_group')
plt.title('Room Types by Neighbourhood Group')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.legend(title='Neighbourhood Group')
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='room_type', data=airbnb)
plt.title('Room Types Distribution')
plt.xlabel('Room Type')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='neighbourhood_group', y='number_of_reviews', data=airbnb, estimator=sum,color='green',width=0.5)
plt.title('Number of Reviews by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Total Number of Reviews')
plt.show()

# %%
review_number = airbnb.groupby('neighbourhood_group')['number_of_reviews'].max().reset_index()
review_number.sort_values(by='number_of_reviews',ascending=False).head(10).reset_index(drop=True)
# Out:
#   neighbourhood_group  number_of_reviews
# 0              Queens                629
# 1           Manhattan                607
# 2            Brooklyn                488
# 3       Staten Island                333
# 4               Bronx                321

# %% [markdown]
# # Availability Throughout the Year

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=airbnb.index, y='availability_365', data=airbnb.sort_values('availability_365'))
plt.title('Availability Throughout the Year')
plt.xlabel('Listing Index (Sorted by Availability)')
plt.ylabel('Availability (in days)')
plt.show()

# %%
price_according_to_reviews= airbnb.groupby(['price'])['number_of_reviews'].max().reset_index()
price_according_to_reviews.sort_values(by='number_of_reviews',ascending=False).head(10).reset_index(drop=True)
# Out:
#    price  number_of_reviews
# 0     47                629
# 1     49                607
# 2     46                543
# 3     99                540
# 4     48                510
# 5    160                488
# 6     60                480
# 7     55                474
# 8    120                467
# 9     65                466

# %%
price_list = price_according_to_reviews['price']
review = price_according_to_reviews['number_of_reviews']
fig=plt.figure(figsize=(8,5))

plt.scatter(price_list,review)
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews VS Price')
plt.show()

# %% [markdown]
# # Busiest Host

# %%
Busy_hosts = airbnb.groupby(['host_id','host_name','room_type'])['number_of_reviews'].max().reset_index()
Busy_hosts.sort_values(by='number_of_reviews',ascending=False).head(10).reset_index(drop=True)
# Out:
#     host_id host_name        room_type  number_of_reviews
# 0  47621202      Dona     Private room                629
# 1   4734398        Jj     Private room                607
# 2  37312959      Maya     Private room                543
# 3   2369681     Carol     Private room                540
# 4  26432133  Danielle     Private room                510
# 5  12949460       Asa  Entire home/apt                488
# 6    792159     Wanda     Private room                480
# 7   2680820     Linda     Private room                474
# 8     42273      Dani  Entire home/apt                467
# 9  23591164    Angela     Private room                466

# %%
Highest_Price = airbnb.groupby(['host_id','host_name','room_type','neighbourhood_group'])['price'].max().reset_index()
Highest_Price.sort_values(by='price',ascending=False).head(10)
# Out:
#          host_id host_name        room_type neighbourhood_group  price
# 8058     5143901      Erin  Entire home/apt            Brooklyn  10000
# 27933   72390391    Jelena  Entire home/apt           Manhattan  10000
# 17067   20582832  Kathrine     Private room              Queens  10000
# 2662     1235070     Olson  Entire home/apt           Manhattan   9999
# 7328     4382127      Matt  Entire home/apt           Manhattan   9999
# 6631     3906464       Amy     Private room           Manhattan   9999
# 16103   18128455       Rum  Entire home/apt           Manhattan   8500
# 2564     1177497   Jessica  Entire home/apt            Brooklyn   8000
# 33439  156158778     Sally  Entire home/apt           Manhattan   7703
# 10118    7407743      Jack  Entire home/apt           Manhattan   7500

# %%
traffic_areas = airbnb.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
traffic_areas.sort_values(by='minimum_nights',ascending=False).head(10).reset_index(drop=True)
# Out:
#   neighbourhood_group        room_type  minimum_nights
# 0           Manhattan  Entire home/apt           13199
# 1            Brooklyn     Private room           10132
# 2            Brooklyn  Entire home/apt            9559
# 3           Manhattan     Private room            7982
# 4              Queens     Private room            3372
# 5              Queens  Entire home/apt            2096
# 6               Bronx     Private room             652
# 7           Manhattan      Shared room             480
# 8            Brooklyn      Shared room             413
# 9               Bronx  Entire home/apt             379

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=traffic_areas['neighbourhood_group'], y=traffic_areas['minimum_nights'], data=airbnb, estimator=sum,color='purple',width=0.8)

plt.xlabel('Areas')
plt.ylabel('Minimum night Counts')

plt.show()

# %%
# Exclude non-numeric columns (object type) from the correlation calculation
numeric_columns = airbnb.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(8, 6))
sns.heatmap(numeric_columns.corr(), annot=True, fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
